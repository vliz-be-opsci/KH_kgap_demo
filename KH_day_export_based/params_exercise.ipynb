# %%
from kg2tbl_tools import execute_to_df, EXPORTFILE, WORKFLDR
from pathlib import Path
print(f"{EXPORTFILE=}, {WORKFLDR=}")
print(f"{Path(EXPORTFILE).exists()=}, {WORKFLDR.exists()=}")
QRYFLDR = WORKFLDR / "queries"
print(f"{QRYFLDR.is_dir()=}")
# Out:
# EXPORTFILE='/home/jovyan/work/20240418_dump_full.ttl', WORKFLDR=PosixPath('/home/jovyan/work')
# Path(EXPORTFILE).exists()=True, WORKFLDR.exists()=True
# QRYFLDR.is_dir()=True

# %% [markdown]
# ## Exercise: Exploration of the knowledge graph

# %%
# pubs for marineinfo person id
marc_mi=38476
katrina_mi=35548
execute_to_df("pubs_for_mi.sparql", id = katrina_mi)
# Out:
#               name                                  orcid
# 0    Katrina Exter  https://orcid.org/0000-0002-5911-1536  \
# 1    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 2    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 3    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 4    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# ..             ...                                    ...
# 148  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 149  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 150  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 151  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 152  Katrina Exter  https://orcid.org/0000-0002-5911-1536
#
#                                                    pub
# 0            https://doi.org/10.1017/s1743921318006385
# 1                  https://doi.org/10.1038/nature09344
# 2    https://rdflib.github.io/.well-known/genid/rdf...
# ...

# %%
# pubs for orcid
marc_orcid="0000-0002-9648-6484"
katrina_orcid="0000-0002-5911-1536"
execute_to_df("pubs_for_orcid.sparql", orcid = katrina_orcid)
# Out:
#               name                                  orcid
# 0    Katrina Exter  https://orcid.org/0000-0002-5911-1536  \
# 1    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 2    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 3    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 4    Katrina Exter  https://orcid.org/0000-0002-5911-1536
# ..             ...                                    ...
# 148  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 149  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 150  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 151  Katrina Exter  https://orcid.org/0000-0002-5911-1536
# 152  Katrina Exter  https://orcid.org/0000-0002-5911-1536
#
#                                                    pub
# 0            https://doi.org/10.1017/s1743921318006385
# 1                  https://doi.org/10.1038/nature09344
# 2    https://rdflib.github.io/.well-known/genid/rdf...
# ...
