# %%
from kgap_tools import execute_to_df, generate_sparql
import pandas as pd

# %% [markdown]
# # Analysis of a Special Collection

# %% [markdown]
# #### What is a special collection?
#
# At VLIZ we manually curate **special collections**, these are collections that groups together datasets, publications, projects, people, institutes and/or events according to a certain topic.
#
# ##### Example:
#
# The special collection we are going to explore is the *Trophos special collection*. This collection contains everything related to the *Trophos project*.
# This was a 4 year research project between 6 institutes that focussed on obtaining at a better understanding of processes structuring the higher trophic levels in the North Sea. (more info: https://www.vliz.be/projects/trophos/index.php)

# %% [markdown]
# #### General information
# First we're going to have a look at general information about the special collection.
#
# To get this information from the graph, we construct a sparql query which you can find under `/queries/spcol_info.sparql`
# With the function `execute_to_df()` this information gets translated into a spreadsheet table.

# %%
spcol_info = execute_to_df("spcol_info.sparql")
spcol_info
# Out:
#                                            spcol  \
# 0     http://dev.marineinfo.org/id/collection/35
# 1     http://dev.marineinfo.org/id/collection/35
# 2     http://dev.marineinfo.org/id/collection/35
# 3     http://dev.marineinfo.org/id/collection/35
# 4     http://dev.marineinfo.org/id/collection/35
# ...                                          ...
# 3327  http://dev.marineinfo.org/id/collection/35
# 3328  http://dev.marineinfo.org/id/collection/35
# 3329  http://dev.marineinfo.org/id/collection/35
# 3330  http://dev.marineinfo.org/id/collection/35
# 3331  http://dev.marineinfo.org/id/collection/35
#
#                                          type    title internal_id  \
# 0     http://purl.org/dc/dcmitype/#Collection  trophos          35
# 1     http://purl.org/dc/dcmitype/#Collection  trophos          35
# 2     http://purl.org/dc/dcmitype/#Collection  trophos          35
# 3     http://purl.org/dc/dcmitype/#Collection  trophos          35
# 4     http://purl.org/dc/dcmitype/#Collection  trophos          35
# ...                                       ...      ...         ...
# 3327  http://purl.org/dc/dcmitype/#Collection  Trophos          35
# 3328  http://purl.org/dc/dcmitype/#Collection  Trophos          35
# 3329  http://purl.org/dc/dcmitype/#Collection  Trophos          35
# 3330  http://purl.org/dc/dcmitype/#Collection  Trophos          35
# 3331  http://purl.org/dc/dcmitype/#Collection  Trophos          35
#
#                                   keywords  \
# 0     https://marineregions.org/mrgid/3293
# 1     https://marineregions.org/mrgid/3293
# 2     https://marineregions.org/mrgid/3293
# 3     https://marineregions.org/mrgid/3293
# 4     https://marineregions.org/mrgid/3293
# ...                                    ...
# 3327  https://marineregions.org/mrgid/5506
# 3328  https://marineregions.org/mrgid/5506
# 3329  https://marineregions.org/mrgid/5506
# 3330  https://marineregions.org/mrgid/5506
# 3331  https://marineregions.org/mrgid/5506
#
#                                                    urls
# 0     http://dev.marineinfo.org/id/collection/www.af...
# 1     http://dev.marineinfo.org/id/collection/www.vl...
# 2     http://dev.marineinfo.org/id/collection/www.na...
# 3     http://dev.marineinfo.org/id/collection/www.vl...
# 4     http://dev.marineinfo.org/id/collection/www.ul...
# ...                                                 ...
# 3327   https://dx.doi.org/10.1016/s1385-1101(02)00165-x
# 3328  http://dev.marineinfo.org/id/collection/www.in...
# 3329  http://dev.marineinfo.org/id/collection/www.vl...
# 3330  http://dev.marineinfo.org/id/collection/www.we...
# 3331  http://dev.marineinfo.org/id/collection/www.ma...
#
# [3332 rows x 6 columns]

# %%
keywords = list(spcol_info.keywords.drop_duplicates())
urls = list(spcol_info.urls.drop_duplicates())

rgid/3446', 'https://marineregions.org/mrgid/3096', 'https://marineregions.org/mrgid/2439', 'https://marineregions.org/mrgid/14804', 'https://marineregions.org/mrgid/5465', 'https://marineregions.org/mrgid/3094', 'https://marineregions.org/mrgid/9105', 'https://marineregions.org/mrgid/5664', 'https://marineregions.org/mrgid/3317', 'https://marineregions.org/mrgid/18584', 'https://marineregions.org/mrgid/3266', 'https://marineregions.org/mrgid/3171', 'https://marineregions.org/mrgid/3691', 'https://marineregions.org/mrgid/5476', 'https://marineregions.org/mrgid/3241', 'https://marineregions.org/mrgid/4279', 'https://marineregions.org/mrgid/17853', 'https://marineregions.org/mrgid/4699', 'https://marineregions.org/mrgid/2165', 'https://marineregions.org/mrgid/4752', 'https://marineregions.org/mrgid/3165', 'https://marineregions.org/mrgid/1912', 'https://marineregions.org/mrgid/2389', 'https://marineregions.org/mrgid/2399', 'https://marineregions.org/mrgid/3414', 'https://marineregions.org/mrgid/5481', 'https://marineregions.org/mrgid/2469', 'https://marineregions.org/mrgid/2438', 'https://marineregions.org/mrgid/4696', 'https://marineregions.org/mrgid/14334', 'https://marineregions.org/mrgid/5542', 'https://marineregions.org/mrgid/2350', 'https://marineregions.org/mrgid/17901', 'https://marineregions.org/mrgid/1904', 'https://marineregions.org/mrgid/1905', 'https://marineregions.org/mrgid/4702', 'https://marineregions.org/mrgid/3475', 'https://marineregions.org/mrgid/5616', 'https://marineregions.org/mrgid/90', 'https://marineregions.org/mrgid/19669', 'https://marineregions.org/mrgid/18579', 'https://marineregions.org/mrgid/2423', 'https://marineregions.org/mrgid/4704', 'https://marineregions.org/mrgid/213', 'https://marineregions.org/mrgid/2432', 'https://marineregions.org/mrgid/1920', 'https://marineregions.org/mrgid/1926', 'https://marineregions.org/mrgid/5506']

# %% [markdown]
# #### Resource information
# Next we're going to have a look a what kind of resources are included in the Trophos special collection.
#
# For this, we execute 2 sparql queries and concatenate the results: `/queries/spcol_resource_datasets.sparql` and `/queries/spcol_resource_other.sparql`
# We then check if there are projects, publications, people, insitutes, events and/or datasets in the special collection

# %%
other_resources = execute_to_df("spcol_resource_other.sparql")

datasets = execute_to_df("spcol_resource_datasets.sparql")
datasets.rename(columns={"dataset": "resource"}, inplace=True)

spcol_resource = pd.concat([other_resources, datasets])
# Out:
#                                              s  \
# 0   http://dev.marineinfo.org/id/collection/35
# 1   http://dev.marineinfo.org/id/collection/35
# 2   http://dev.marineinfo.org/id/collection/35
# 3   http://dev.marineinfo.org/id/collection/35
# 4   http://dev.marineinfo.org/id/collection/35
# ..                                         ...
# 31  http://dev.marineinfo.org/id/collection/35
# 32  http://dev.marineinfo.org/id/collection/35
# 33  http://dev.marineinfo.org/id/collection/35
# 34  http://dev.marineinfo.org/id/collection/35
# 35  http://dev.marineinfo.org/id/collection/35
#
#                                           resource
# 0        http://dev.marineinfo.org/id/project/2051
# 1           http://dev.marineinfo.org/id/event/185
# 2   http://dev.marineinfo.org/id/publication/57828
# 3   http://dev.marineinfo.org/id/publication/71914
# 4   http://dev.marineinfo.org/id/publication/72052
# ..                                             ...
# 31        http://dev.marineinfo.org/id/dataset/148
# 32         http://dev.marineinfo.org/id/dataset/36
# 33         http://dev.marineinfo.org/id/dataset/71
# 34       http://dev.marineinfo.org/id/dataset/1848
# 35        http://dev.marineinfo.org/id/dataset/960
#
# [174 rows x 2 columns]

# %%
#Number of unique resources in the special collection
unique_resources = spcol_resource.groupby('resource').nunique().reset_index()
print(f"The special collection contains {unique_resources.shape[0]} unique resources.")
# Out:
# The special collection contains 174 unique resources

# %%
#projects
projects = spcol_resource[ spcol_resource.resource.str.contains('project') ]
projects.groupby('resource').nunique()
# Out:
#                                            s
# resource
# http://dev.marineinfo.org/id/project/1074  1
# http://dev.marineinfo.org/id/project/1075  1
# http://dev.marineinfo.org/id/project/2051  1

# %%
#Publications
publications = spcol_resource[ spcol_resource.resource.str.contains('publication') ]
publications.groupby('resource').nunique()
# Out:
#                                                  s
# resource
# http://dev.marineinfo.org/id/publication/103102  1
# http://dev.marineinfo.org/id/publication/108115  1
# http://dev.marineinfo.org/id/publication/108179  1
# http://dev.marineinfo.org/id/publication/110144  1
# http://dev.marineinfo.org/id/publication/110149  1
# ...                                             ..
# http://dev.marineinfo.org/id/publication/97429   1
# http://dev.marineinfo.org/id/publication/97433   1
# http://dev.marineinfo.org/id/publication/97552   1
# http://dev.marineinfo.org/id/publication/97958   1
# http://dev.marineinfo.org/id/publication/98082   1
#
# [121 rows x 1 columns]

# %%
#People
people = spcol_resource[ spcol_resource.resource.str.contains('person') ]
# Out:
# Empty DataFrame
# Columns: [s, resource]
# Index: []

# %%
#Organizations/Institutes
institutes = spcol_resource[ spcol_resource.resource.str.contains('institute') ]
# Out:
# Empty DataFrame
# Columns: [s, resource]
# Index: []

# %%
#Events
events = spcol_resource[ spcol_resource.resource.str.contains('event') ]
# Out:
#                                               s  \
# 1    http://dev.marineinfo.org/id/collection/35
# 9    http://dev.marineinfo.org/id/collection/35
# 24   http://dev.marineinfo.org/id/collection/35
# 26   http://dev.marineinfo.org/id/collection/35
# 35   http://dev.marineinfo.org/id/collection/35
# 43   http://dev.marineinfo.org/id/collection/35
# 49   http://dev.marineinfo.org/id/collection/35
# 60   http://dev.marineinfo.org/id/collection/35
# 69   http://dev.marineinfo.org/id/collection/35
# 70   http://dev.marineinfo.org/id/collection/35
# 79   http://dev.marineinfo.org/id/collection/35
# 80   http://dev.marineinfo.org/id/collection/35
# 94   http://dev.marineinfo.org/id/collection/35
# 114  http://dev.marineinfo.org/id/collection/35
#
#                                    resource
# 1    http://dev.marineinfo.org/id/event/185
# 9    http://dev.marineinfo.org/id/event/363
# 24   http://dev.marineinfo.org/id/event/356
# 26   http://dev.marineinfo.org/id/event/355
# 35   http://dev.marineinfo.org/id/event/360
# 43   http://dev.marineinfo.org/id/event/352
# 49   http://dev.marineinfo.org/id/event/359
# 60   http://dev.marineinfo.org/id/event/358
# 69   http://dev.marineinfo.org/id/event/353
# 70   http://dev.marineinfo.org/id/event/362
# 79   http://dev.marineinfo.org/id/event/180
# 80   http://dev.marineinfo.org/id/event/351
# 94   http://dev.marineinfo.org/id/event/364
# 114  http://dev.marineinfo.org/id/event/357

# %%
#Datasets
datasets = spcol_resource[ spcol_resource.resource.str.contains('dataset') ]
# Out:
#                                              s  \
# 0   http://dev.marineinfo.org/id/collection/35
# 1   http://dev.marineinfo.org/id/collection/35
# 2   http://dev.marineinfo.org/id/collection/35
# 3   http://dev.marineinfo.org/id/collection/35
# 4   http://dev.marineinfo.org/id/collection/35
# 5   http://dev.marineinfo.org/id/collection/35
# 6   http://dev.marineinfo.org/id/collection/35
# 7   http://dev.marineinfo.org/id/collection/35
# 8   http://dev.marineinfo.org/id/collection/35
# 9   http://dev.marineinfo.org/id/collection/35
# 10  http://dev.marineinfo.org/id/collection/35
# 11  http://dev.marineinfo.org/id/collection/35
# 12  http://dev.marineinfo.org/id/collection/35
# 13  http://dev.marineinfo.org/id/collection/35
# 14  http://dev.marineinfo.org/id/collection/35
# 15  http://dev.marineinfo.org/id/collection/35
# 16  http://dev.marineinfo.org/id/collection/35
# 17  http://dev.marineinfo.org/id/collection/35
# 18  http://dev.marineinfo.org/id/collection/35
# 19  http://dev.marineinfo.org/id/collection/35
# 20  http://dev.marineinfo.org/id/collection/35
# 21  http://dev.marineinfo.org/id/collection/35
# 22  http://dev.marineinfo.org/id/collection/35
# 23  http://dev.marineinfo.org/id/collection/35
# 24  http://dev.marineinfo.org/id/collection/35
# 25  http://dev.marineinfo.org/id/collection/35
# 26  http://dev.marineinfo.org/id/collection/35
# 27  http://dev.marineinfo.org/id/collection/35
# 28  http://dev.marineinfo.org/id/collection/35
# 29  http://dev.marineinfo.org/id/collection/35
# 30  http://dev.marineinfo.org/id/collection/35
# 31  http://dev.marineinfo.org/id/collection/35
# 32  http://dev.marineinfo.org/id/collection/35
# 33  http://dev.marineinfo.org/id/collection/35
# 34  http://dev.marineinfo.org/id/collection/35
# 35  http://dev.marineinfo.org/id/collection/35
#
#                                      resource
# 0     http://dev.marineinfo.org/id/dataset/55
# 1    http://dev.marineinfo.org/id/dataset/209
# 2     http://dev.marineinfo.org/id/dataset/70
# 3     http://dev.marineinfo.org/id/dataset/72
# 4     http://dev.marineinfo.org/id/dataset/62
# 5   http://dev.marineinfo.org/id/dataset/1428
# 6    http://dev.marineinfo.org/id/dataset/156
# 7     http://dev.marineinfo.org/id/dataset/23
# 8    http://dev.marineinfo.org/id/dataset/210
# 9    http://dev.marineinfo.org/id/dataset/472
# 10   http://dev.marineinfo.org/id/dataset/149
# 11  http://dev.marineinfo.org/id/dataset/1846
# 12    http://dev.marineinfo.org/id/dataset/38
# 13    http://dev.marineinfo.org/id/dataset/51
# 14   http://dev.marineinfo.org/id/dataset/153
# 15    http://dev.marineinfo.org/id/dataset/24
# 16  http://dev.marineinfo.org/id/dataset/1845
# 17    http://dev.marineinfo.org/id/dataset/40
# 18    http://dev.marineinfo.org/id/dataset/39
# 19   http://dev.marineinfo.org/id/dataset/992
# 20    http://dev.marineinfo.org/id/dataset/53
# 21   http://dev.marineinfo.org/id/dataset/139
# 22   http://dev.marineinfo.org/id/dataset/829
# 23     http://dev.marineinfo.org/id/dataset/7
# 24    http://dev.marineinfo.org/id/dataset/77
# 25    http://dev.marineinfo.org/id/dataset/35
# 26    http://dev.marineinfo.org/id/dataset/25
# 27   http://dev.marineinfo.org/id/dataset/167
# 28    http://dev.marineinfo.org/id/dataset/37
# 29   http://dev.marineinfo.org/id/dataset/162
# 30    http://dev.marineinfo.org/id/dataset/41
# 31   http://dev.marineinfo.org/id/dataset/148
# 32    http://dev.marineinfo.org/id/dataset/36
# 33    http://dev.marineinfo.org/id/dataset/71
# 34  http://dev.marineinfo.org/id/dataset/1848
# 35   http://dev.marineinfo.org/id/dataset/960
