# %%
from kgap_tools import execute_to_df, generate_sparql

# %%
all_data = execute_to_df("all.sparql")

# %%
all_data
# Out:
#                                                       s  \
# 0                             https://ror.org/00cv9y106
# 1                             https://ror.org/04pm4x478
# 2                             https://ror.org/03prydq77
# 3                             https://ror.org/0496vr396
# 4                             https://ror.org/01621q256
# ...                                                 ...
# 3905  https://rdflib.github.io/.well-known/genid/rdf...
# 3906  https://rdflib.github.io/.well-known/genid/rdf...
# 3907  https://rdflib.github.io/.well-known/genid/rdf...
# 3908  https://rdflib.github.io/.well-known/genid/rdf...
# 3909  https://rdflib.github.io/.well-known/genid/rdf...
#
#                                                     p  \
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...

# %%
collection_data = execute_to_df("test.sparql")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/SPARQLWrapper/Wrapper.py:926, in SPARQLWrapper._query(self)
#     925 else:
# --> 926     response = urlopener(request)
#     927 return response, self.returnFormat
#
# File /opt/conda/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /opt/conda/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /opt/conda/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# ...
